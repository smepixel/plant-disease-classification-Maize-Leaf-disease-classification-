# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Step 1: Install the necessary packages
# !pip install pyngrok

# !pip install -r "/content/drive/MyDrive/Plant_disease_detection/requirements.txt"
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.10/dist-packages (7.2.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: numpy==1.26.3 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 1)) (1.26.3)
# Requirement already satisfied: scikit-learn==1.3.2 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: streamlit==1.29.0 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (1.29.0)
# Requirement already satisfied: streamlit-option-menu==0.3.6 in /usr/local/lib/python3.10/dist-packages (from -r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 4)) (0.3.6)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.2->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.2->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn==1.3.2->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (8.1.7)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (6.11.0)
# Requirement already satisfied: packaging<24,>=16.8 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (10.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (3.20.3)
# Requirement already satisfied: pyarrow>=6.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (16.1.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.3 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (13.8.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (5.2)
# Requirement already satisfied: validators<1,>=0.2 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (0.34.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (6.3.3)
# Requirement already satisfied: watchdog>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (5.0.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<7,>=1.4->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (3.20.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3,>=2.7.3->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (0.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit==1.29.0->-r /content/drive/MyDrive/Plant_disease_detection/requirements.txt (line 3)) (0.1.2)

# %%
import os
from threading import Thread
from pyngrok import ngrok

# %%
# Add your ngrok token here
ngrok.set_auth_token('2hlLLfmUqXvbe7YXIvYaOrNX5Gb_4cSbHMvYBrNPsqRuY2xKK')

# %%
def run_streamlit():
    # Change the port if 8501 is already in use or if you prefer another port
    os.system('streamlit run /content/drive/MyDrive/Plant_disease_detection/app.py --server.port 8501')

# %%
# Start a thread to run the Streamlit app
thread = Thread(target=run_streamlit)
thread.start()

# %%
# Open a tunnel to the streamlit port 8501
public_url = ngrok.connect(addr='8501', proto='http', bind_tls=True)
print('Your Streamlit app is live at:', public_url)
# Out:
# Your Streamlit app is live at: NgrokTunnel: "https://fa04-34-170-12-43.ngrok-free.app" -> "http://localhost:8501"

# %%
#ngrok.kill()
